# %%
import sys

sys.path.append("/Workspace/Users/job@kesavaramgoda1gmail.onmicrosoft.com/")

# %%
from utils import greet, add_numbers

# %%
print(greet("Kesava"))

result = add_numbers(10, 20)

print(result)
